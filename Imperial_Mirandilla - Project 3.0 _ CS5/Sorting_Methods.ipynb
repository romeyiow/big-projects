# %%
def bubbleSort (aList):
    for passnum in range (len(aList) - 1 , 0 , -1 ) :
        for i in range ( passnum ):
            if aList[i] > aList[i + 1] :
                temp = aList[i]
                aList[i] = aList[i + 1]
                aList[i + 1] = temp
    return aList

# %%
def selectionSort (aList):
    for fillslot in range (len(aList) - 1, 0, -1):
        positionOfMax = 0
        for location in range (1, fillslot + 1):
            if aList [location] > aList [positionOfMax]:
                positionOfMax = location
        temp = aList [fillslot]
        aList [fillslot] = aList [positionOfMax]
        aList[positionOfMax] = temp
        
    return aList

# %%
def quickSort(arr):
    pivot = arr [0]
    left = list()
    right = list()
    for i in arr:
        if i < pivot:
            left.append(i)
        elif i > pivot:
            right.append(i)
            
    if len(left) >= 2:
        left = quick_sort(left)
        print(*left)
    if len(right) >= 2:
        right = quick_sort(right)
        print(*right)
    return left + [pivot] + right

# %%
""""
def resetBasis(prev,new,aList,ylim):
    if prev == new:
        liftBox(prev,aList,ylim)        
    else:
        returnBox(prev,aList,ylim)
        liftBox(new,aList,300)
        

    
def returnBox(loc,aList,ylim):
    jx1, jy1, jx2, jy2 = canvas_sorting.bbox("rect_{}".format(aList[loc]))
    #print('return:',jy1)
    if jy1 == 400:
        return
    else:
        canvas_sorting.move('rect_{}'.format(aList[loc]),0,1)
    rtMain.update()
    canvas_sorting.after(0,returnBox(loc,aList,ylim))       

def returnBothBox(posMax,loc,aList,ylim):
    jx1, jy1, jx2, jy2 = canvas_sorting.bbox("rect_{}".format(aList[posMax]))
    kx1, ky1, kx2, ky2 = canvas_sorting.bbox("rect_{}".format(aList[loc]))
    #print('return:',jy1)
    if jy1 == 400:
        pass
    else:
        canvas_sorting.move('rect_{}'.format(aList[posMax]),0,4)
    if ky1 == 400:
        pass
    else:
        canvas_sorting.move('rect_{}'.format(aList[loc]),0,-4)
    if jy1 == 400 and ky1 == 400:
        return
    rtMain.update()
    canvas_sorting.after(0,returnBothBox(posMax,loc,aList,ylim)) 
    
def liftBox(loc,aList,ylim):
    jx1, jy1, jx2, jy2 = canvas_sorting.bbox("rect_{}".format(aList[loc]))
    #print('lift:',jy1)
    corrector = 1
    if jy1 < ylim:
        corrector = -1
    if jy1 == ylim:
        return
    else:
        canvas_sorting.move('rect_{}'.format(aList[loc]),0,-.25*corrector)
    rtMain.update()
    canvas_sorting.after(0,liftBox(loc,aList,ylim))
    
def dropBox(loc,aList,ylim):
    jx1, jy1, jx2, jy2 = canvas_sorting.bbox("rect_{}".format(aList[loc]))
    #print('lift:',jy1)
    if jy1 == ylim:
        return
    else:
        canvas_sorting.move('rect_{}'.format(aList[loc]),0,1)
    rtMain.update()
    canvas_sorting.after(0,dropBox(loc,aList,ylim))  
    
def settleMax(posMax,lim,plim,xlim,aList):
    if posMax != lim:
        dropBox(lim,aList,500)
        jx1, jy1, jx2, jy2 = canvas_sorting.bbox("rect_{}".format(aList[posMax]))
        kx1, ky1, kx2, ky2 = canvas_sorting.bbox("rect_{}".format(aList[lim]))
        #print('swap:',jx1)
        if jx1 == xlim:
            pass
        else:
            canvas_sorting.move('rect_{}'.format(aList[posMax]),10,0)
        if kx1 == plim:
            pass
        else:
            canvas_sorting.move('rect_{}'.format(aList[lim]),-10,0)
        if jx1 == xlim and  kx1 == plim:
            returnBothBox(posMax,lim,aList,400)
            return
        rtMain.update()
        
        canvas_sorting.after(0,settleMax(posMax,lim,plim,xlim,aList))
    else:
        returnBox(posMax,aList,400)
        
def selectionSort (aList):
    for fillslot in range (len(aList) - 1, 0, -1):
        positionOfMax = 0
        ylim = 300
        resetBasis(positionOfMax,0,aList,ylim)
        for location in range (1, fillslot + 1):
            ylim = 370
            liftBox(location,aList,ylim)
            if aList [location] > aList [positionOfMax]:
                resetBasis(positionOfMax,location,aList,ylim)
                positionOfMax = location
            else:
                returnBox(location,aList,ylim)
        temp = aList [fillslot]
        jx1, jy1, jx2, jy2 = canvas_sorting.bbox("rect_{}".format(aList[positionOfMax]))
        kx1, ky1, kx2, ky2 = canvas_sorting.bbox("rect_{}".format(aList[fillslot]))
        settleMax(positionOfMax,fillslot,jx1,kx1,aList)
        aList [fillslot] = aList [positionOfMax]
        aList[positionOfMax] = temp
        """

# %%
"""
def liftMark(loc,direction,goal,aList):
    if abs(loc) < len(aList):
        jx1, jy1, jx2, jy2 = canvas_sorting.bbox("rect_{}".format(aList[loc]))
        #print('JY1:',jy1)
        if jy1 == goal:
            return
        else:
            canvas_sorting.move('rect_{}'.format(aList[loc]),0,-0.5*direction)

        rtMain.update()
        canvas_sorting.after(0,liftMark(loc,direction,goal,aList))  
    else:
        return
def settleMarks(rightmark,leftmark,aList):
    if rightmark != leftmark:
        lx1, ly1, lx2, ly2 = canvas_sorting.bbox("rect_{}".format(aList[leftmark])) 
        rx1, ry1, rx2, ry2 = canvas_sorting.bbox("rect_{}".format(aList[rightmark])) 

        if ly1 == 350:
            rtMain.update()
            pass
        else:
            canvas_sorting.move('rect_{}'.format(aList[leftmark]),0,-1)
        if ry1 == 450:
            rtMain.update()
            pass
        else:
            canvas_sorting.move('rect_{}'.format(aList[rightmark]),0,1)
        if ly1 == 350 and ry1 == 450:
            rtMain.update()
            return
        rtMain.update()
        canvas_sorting.after(0,settleMarks(rightmark,leftmark,aList))
    else:
        return
    
def swapMarks(leftmark,rightmark,Llim,Rlim,aList):
    
    lx1, ly1, lx2, ly2 = canvas_sorting.bbox("rect_{}".format(aList[leftmark])) 
    rx1, ry1, rx2, ry2 = canvas_sorting.bbox("rect_{}".format(aList[rightmark])) 

    if lx1 == Rlim:
        pass
    else:
        canvas_sorting.move('rect_{}'.format(aList[leftmark]),1,0)
    if rx1 == Llim:
        pass
    else:
        canvas_sorting.move('rect_{}'.format(aList[rightmark]),-1,0)
    
    if lx1 == Rlim and  rx1 == Llim:
       
        return
    rtMain.update()
    canvas_sorting.after(0,swapMarks(leftmark,rightmark,Llim,Rlim,aList))

def swapRightAndPivot(start,rightmark,Slim,Rlim,aList):
    sx1, sy1, sx2, sy2 = canvas_sorting.bbox("rect_{}".format(aList[start])) 
    rx1, ry1, rx2, ry2 = canvas_sorting.bbox("rect_{}".format(aList[rightmark]))  

    if sx1 == Rlim:
        pass
    else:
        canvas_sorting.move('rect_{}'.format(aList[start]),2,0)
    
    if rx1 == Slim:
        pass
    
    else:
        canvas_sorting.move('rect_{}'.format(aList[rightmark]),-2,0)
    
    if sx1 == Rlim and  rx1 == Slim:
        return
    
    rtMain.update()
    canvas_sorting.after(0,swapRightAndPivot(start,rightmark,Slim,Rlim,aList))

    
def resetAll(aList):
    for loc in range (len(aList)):
        jx1, jy1, jx2, jy2 = canvas_sorting.bbox("rect_{}".format(aList[loc]))
        if jy1 < 400: #(loc,direction,goal,aList)
            #liftMark(loc,-1,400,aList)
            pass
        elif jy1 > 400:
            #liftMark(loc,1,400,aList)            
            pass
    return
def quickSort(aList,start,end,pas):
    pivotvalue = aList [start]

    leftmark = start + 1 
    rightmark = end
    #print('List:',aList)
    #print('Starting Rightmark',rightmark)
    #print('Starting Leftmark',leftmark)
    
    done = False

    #liftMark(leftmark,-1,450,aList)
    #liftMark(rightmark,1,350,aList)
    
    
    while not done:
         
        while leftmark <= rightmark and aList[leftmark] <=  pivotvalue:
            leftmark = leftmark + 1
            if leftmark < rightmark:
                #liftMark(leftmark,-1,450,aList)
                pass
        while  rightmark >= leftmark and aList[rightmark] >=  pivotvalue:    
            rightmark = rightmark - 1
            if rightmark >= leftmark:
                #liftMark(rightmark,1,350,aList)
                pass
            elif rightmark < leftmark:
                #liftMark(rightmark,1,400,aList)
                pass
       
        if rightmark < leftmark:
            #print('Last Rightmark',rightmark)
            #print('Last Leftmark',leftmark)
            #liftMark(rightmark,-1,400,aList)
            sx1, sy1, sx2, sy2 = canvas_sorting.bbox("rect_{}".format(aList[start])) 
            rx1, ry1, rx2, ry2 = canvas_sorting.bbox("rect_{}".format(aList[rightmark])) 

            swapRightAndPivot(start,rightmark,sx1,rx1,aList)
            done = True
                
        else: 
            lx1, ly1, lx2, ly2 = canvas_sorting.bbox("rect_{}".format(aList[leftmark])) 
            rx1, ry1, rx2, ry2 = canvas_sorting.bbox("rect_{}".format(aList[rightmark])) 
            #settleMarks(rightmark,leftmark,aList)
            swapMarks(leftmark,rightmark,lx1,rx1,aList)
           
            
            temp = aList [leftmark]
            aList [leftmark] = aList[rightmark]
            aList [rightmark] = temp

    
    
    temp = aList [start]
    aList[start] = aList[rightmark]
    aList[rightmark] = temp

    #resetAll(aList)

    leftSide = aList[start:rightmark]
    rightSide = aList[rightmark+1:end+1]

    #print('left',*leftSide)
    #print('right',*rightSide)
    #print (*leftSide,'|',*rightSide)
    #return
    #time.sleep(2)
    if len(leftSide) >= 2:
        #print('Left Pass #',pas)
        resetAll(leftSide)
        leftSide = quickSort(leftSide,0,len(leftSide)-1,pas+1)

    if len(rightSide) >= 2:
        #print('Right Pass #',pas)
        resetAll(rightSide)
        rightSide = quickSort(rightSide,0,len(rightSide)-1,pas+1)
        
    resetAll(leftSide + [pivotvalue] + rightSide)
    return leftSide + [pivotvalue] + rightSide
    """

# %%
"""


global x
x = random.sample(range(50),50)
#print(x)
start = Color('pink')
end = Color('cyan')
c = list(start.range_to(end,50))        

def liftMark(loc,direction,goal,aList,speed):
    if abs(loc) < len(aList):
        jx1, jy1, jx2, jy2 = canvas_sorting.bbox("rect_{}".format(aList[loc]))
        #print('JY1:',jy1)
        if jy1 == goal:
            return
        else:
            canvas_sorting.move('rect_{}'.format(aList[loc]),0,speed*direction)

        rtMain.update()
        canvas_sorting.after(0,liftMark(loc,direction,goal,aList,speed))  
    else:
        return
def settleMarks(rightmark,leftmark,aList):
    if rightmark != leftmark:
        lx1, ly1, lx2, ly2 = canvas_sorting.bbox("rect_{}".format(aList[leftmark])) 
        rx1, ry1, rx2, ry2 = canvas_sorting.bbox("rect_{}".format(aList[rightmark])) 

        if ly1 == 350:
            rtMain.update()
            pass
        else:
            canvas_sorting.move('rect_{}'.format(aList[leftmark]),0,-1)
        if ry1 == 450:
            rtMain.update()
            pass
        else:
            canvas_sorting.move('rect_{}'.format(aList[rightmark]),0,1)
        if ly1 == 350 and ry1 == 450:
            rtMain.update()
            return
        rtMain.update()
        canvas_sorting.after(0,settleMarks(rightmark,leftmark,aList))
    else:
        return
    
def swapMarks(leftmark,rightmark,Llim,Rlim,aList):
    
    lx1, ly1, lx2, ly2 = canvas_sorting.bbox("rect_{}".format(aList[leftmark])) 
    rx1, ry1, rx2, ry2 = canvas_sorting.bbox("rect_{}".format(aList[rightmark])) 

    if lx1 == Rlim:
        pass
    else:
        canvas_sorting.move('rect_{}'.format(aList[leftmark]),5,0)
    if rx1 == Llim:
        pass
    else:
        canvas_sorting.move('rect_{}'.format(aList[rightmark]),-5,0)
    
    if lx1 == Rlim and  rx1 == Llim:
       
        return
    rtMain.update()
    canvas_sorting.after(0,swapMarks(leftmark,rightmark,Llim,Rlim,aList))

def swapRightAndPivot(start,rightmark,Slim,Rlim,aList):
    sx1, sy1, sx2, sy2 = canvas_sorting.bbox("rect_{}".format(aList[start])) 
    rx1, ry1, rx2, ry2 = canvas_sorting.bbox("rect_{}".format(aList[rightmark]))  

    if sx1 == Rlim:
        pass
    else:
        canvas_sorting.move('rect_{}'.format(aList[start]),2,0)
    
    if rx1 == Slim:
        pass
    
    else:
        canvas_sorting.move('rect_{}'.format(aList[rightmark]),-2,0)
    
    if sx1 == Rlim and  rx1 == Slim:
        return
    
    rtMain.update()
    canvas_sorting.after(0,swapRightAndPivot(start,rightmark,Slim,Rlim,aList))

    
def resetAll(aList):
    for loc in range (len(aList)):
        jx1, jy1, jx2, jy2 = canvas_sorting.bbox("rect_{}".format(aList[loc]))
        if jy1 < 400: #(loc,direction,goal,aList)
            liftMark(loc,1,400,aList,1)
        elif jy1 > 400:
            liftMark(loc,-1,400,aList,1)            
    
    return
def quickSort(aList,start,end,pas):
    pivotvalue = aList [start]

    leftmark = start + 1 
    rightmark = end
    #print('List:',aList)
    #print('Starting Rightmark',rightmark)
    #print('Starting Leftmark',leftmark)
    
    done = False

    liftMark(leftmark,1,450,aList,0.25)
    liftMark(rightmark,-1,350,aList,0.25)
    
    while not done:
         
        while leftmark <= rightmark and aList[leftmark] <=  pivotvalue:
            leftmark = leftmark + 1
            if leftmark < rightmark:
                liftMark(leftmark,1,450,aList,0.25)
        
        while  rightmark >= leftmark and aList[rightmark] >=  pivotvalue:    
            rightmark = rightmark - 1
            if rightmark >= leftmark:
                liftMark(rightmark,-1,350,aList,0.25)
            elif rightmark < leftmark:
                liftMark(rightmark,-1,400,aList,0.25)
       
        if rightmark < leftmark:
            #print('Last Rightmark',rightmark)
            #print('Last Leftmark',leftmark)
            #liftMark(rightmark,-1,400,aList)
            sx1, sy1, sx2, sy2 = canvas_sorting.bbox("rect_{}".format(aList[start])) 
            rx1, ry1, rx2, ry2 = canvas_sorting.bbox("rect_{}".format(aList[rightmark])) 

            swapRightAndPivot(start,rightmark,sx1,rx1,aList)
            done = True
                
        else: 
            lx1, ly1, lx2, ly2 = canvas_sorting.bbox("rect_{}".format(aList[leftmark])) 
            rx1, ry1, rx2, ry2 = canvas_sorting.bbox("rect_{}".format(aList[rightmark])) 
            settleMarks(rightmark,leftmark,aList)
            swapMarks(leftmark,rightmark,lx1,rx1,aList)
           
            
            temp = aList [leftmark]
            aList [leftmark] = aList[rightmark]
            aList [rightmark] = temp

    
    
    temp = aList [start]
    aList[start] = aList[rightmark]
    aList[rightmark] = temp

    #resetAll(aList)

    leftSide = aList[start:rightmark]
    rightSide = aList[rightmark+1:end+1]

    #print('left',*leftSide)
    #print('right',*rightSide)
    #print (*leftSide,'|',*rightSide)
    #return
    #time.sleep(2)
    if len(leftSide) >= 2:
        #print('Left Pass #',pas)
        resetAll(leftSide)
        leftSide = quickSort(leftSide,0,len(leftSide)-1,pas+1)

    if len(rightSide) >= 2:
        #print('Right Pass #',pas)
        resetAll(rightSide)
        rightSide = quickSort(rightSide,0,len(rightSide)-1,pas+1)
    resetAll(leftSide + [pivotvalue] + rightSide)
    return leftSide + [pivotvalue] + rightSide
def callB():
    global x
    #selectionSort(x)
    newbubble(x)
    #quickSort(x,0,len(x)-1,1)
rtMain = Tk()
rtMain.geometry("1020x700+300+50")
rtMain.title('SORTING MEETS HUE')
rtMain.config(bg = clr[2])
canvas_sorting = Canvas(rtMain, width = 1020, height = 1020)
canvas_sorting.config(bg = clr[1], bd = 0,highlightthickness = 0,highlightbackground = clr[2])
canvas_sorting.pack()

for i in range(50):
    exec('global canvas_{0}'.format(i))
    exec('canvas_{0} = Canvas(canvas_sorting, width = 20, height = 20)'.format(i))
    exec('canvas_{0}.config(bg = c[{1}], bd = 0,highlightthickness = 0)'.format(i,i))
    exec('canvas_sorting.create_window(20+({1}*20),265,window = canvas_{2})'.format(i,i,i))

for i in range(50):
    canvas_sorting.create_rectangle(10+i*20, 400, 29+i*20, 490, fill = c[x[i]], outline =c[x[i]], tags = 'rect_{}'.format(x[i]))
but = Button(canvas_sorting, text = 'Sort',command = callB)
canvas_sorting.create_window(520,20,window = but)

rtMain.mainloop()
"""
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\student b35\Anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-6-8bfe201b0712>", line 220, in callB
#     quickSort(x,0,len(x)-1,1)
#   File "<ipython-input-6-8bfe201b0712>", line 182, in quickSort
#     swapMarks(leftmark,rightmark,lx1,rx1,aList)
#   File "<ipython-input-6-8bfe201b0712>", line 107, in swapMarks
#     canvas_sorting.after(0,swapMarks(leftmark,rightmark,Llim,Rlim,aList))
#   File "<ipython-input-6-8bfe201b0712>", line 107, in swapMarks
#     canvas_sorting.after(0,swapMarks(leftmark,rightmark,Llim,Rlim,aList))
#   File "<ipython-input-6-8bfe201b0712>", line 107, in swapMarks
#     canvas_sorting.after(0,swapMarks(leftmark,rightmark,Llim,Rlim,aList))
#   [Previous line repeated 2948 more times]
#   File "<ipython-input-6-8bfe201b0712>", line 91, in swapMarks
# ...

# %%
"""def updateOrder(n,jx,kx,aList):
    canvas_sorting.move('rect_{}'.format(aList[n]),-0.5,0)
    canvas_sorting.move('rect_{}'.format(aList[n+1]),0.5,0)
    
    jx1, jy1, jx2, jy2 = canvas_sorting.bbox("rect_{}".format(aList[n]))
    kx1, ky1, kx2, kcury2 = canvas_sorting.bbox("rect_{}".format(aList[n+1]))
   
    if jx1 == kx:
        return
    rtMain.update()
    canvas_sorting.after(0, updateOrder(n,jx,kx,aList))
    
def prepare_ToCompare(n,aList,j,k):
    canvas_sorting.move('rect_{}'.format(aList[n]),0,0.25)
    canvas_sorting.move('rect_{}'.format(aList[n+1]),0,-0.25)
    jx1, jy1, jx2, jy2 = canvas_sorting.bbox("rect_{}".format(aList[n]))
    print(jy1)
    kx1, ky1, kx2, ky2 = canvas_sorting.bbox("rect_{}".format(aList[n+1]))
    #print('prepare:',jy1)
    if jy1 == 450:
        return
    rtMain.update()
    canvas_sorting.after(0,prepare_ToCompare(n,aList,j,k))

def reset_ToCompare(n,aList,j,k):
    jx1, jy1, jx2, jy2 = canvas_sorting.bbox("rect_{}".format(aList[n]))
    kx1, ky1, kx2, ky2 = canvas_sorting.bbox("rect_{}".format(aList[n+1]))
    #print('reset:',jy1)
    if jy1 == 400:
        pass
    else:
        canvas_sorting.move('rect_{}'.format(aList[n]),0,j)
    if ky1 == 400:
        pass
    else:
        canvas_sorting.move('rect_{}'.format(aList[n+1]),0,k)
    if jy1 == 400 and jy1 == 400:
        return
    rtMain.update()
    canvas_sorting.after(0,reset_ToCompare(n,aList,j,k))
    
def newbubble (aList):
    exchanges = True
    passnum = len(aList) - 1
    while passnum > 0 and exchanges:
        exchanges = False
        for i in range (passnum):
            prepare_ToCompare(i,aList,0.5,-0.5)
            if aList[i] > aList[i+1]:
                exchanges = True
                temp = aList[i]
                aList[i] = aList[i+1]
                aList[i+1] = temp
                jx1, jy1, jx2, jy2 = canvas_sorting.bbox('rect_{0}'.format(aList[i]))
                print(jy1)
                kx1, ky1, kx2, ky2 = canvas_sorting.bbox('rect_{0}'.format(aList[i+1]))
                updateOrder(i,jx1,kx1,aList)
                rtMain.update()
                reset_ToCompare(i,aList,0.5,-0.5) 
            else:
                rtMain.update()
                reset_ToCompare(i,aList,-0.5,0.5) 
        passnum -= 1 
        
#--------------------------Selection Sort----------------        
def resetBasis(prev,new,aList,ylim):
    return
    if prev == new:
        liftBox(prev,aList,ylim)        
    else:
        returnBox(prev,aList,ylim)
        liftBox(new,aList,300)
        

    
def returnBox(loc,aList,ylim):
    jx1, jy1, jx2, jy2 = canvas_sorting.bbox("rect_{}".format(aList[loc]))

    if jy1 == 400:
        return
    else:
        canvas_sorting.move('rect_{}'.format(aList[loc]),0,1)
    rtMain.update()
    canvas_sorting.after(0,returnBox(loc,aList,ylim))       

def returnBothBox(posMax,loc,aList,ylim):
    jx1, jy1, jx2, jy2 = canvas_sorting.bbox("rect_{}".format(aList[posMax]))
    kx1, ky1, kx2, ky2 = canvas_sorting.bbox("rect_{}".format(aList[loc]))
   
    if jy1 == 400:
        pass
    else:
        canvas_sorting.move('rect_{}'.format(aList[posMax]),0,4)
    if ky1 == 400:
        pass
    else:
        canvas_sorting.move('rect_{}'.format(aList[loc]),0,-4)
    if jy1 == 400 and ky1 == 400:
        return
    rtMain.update()
    canvas_sorting.after(0,returnBothBox(posMax,loc,aList,ylim)) 
    
def liftBox(loc,aList,ylim):
    jx1, jy1, jx2, jy2 = canvas_sorting.bbox("rect_{}".format(aList[loc]))

    corrector = 1
    if jy1 < ylim:
        corrector = -1
    if jy1 == ylim:
        return
    else:
        canvas_sorting.move('rect_{}'.format(aList[loc]),0,-.25*corrector)
    rtMain.update()
    canvas_sorting.after(0,liftBox(loc,aList,ylim))
    
def dropBox(loc,aList,ylim):
    jx1, jy1, jx2, jy2 = canvas_sorting.bbox("rect_{}".format(aList[loc]))
    if jy1 == ylim:
        return
    else:
        canvas_sorting.move('rect_{}'.format(aList[loc]),0,1)
    rtMain.update()
    canvas_sorting.after(0,dropBox(loc,aList,ylim))  
    
def settleMax(posMax,lim,plim,xlim,aList):
    if posMax != lim:
        dropBox(lim,aList,500)
        jx1, jy1, jx2, jy2 = canvas_sorting.bbox("rect_{}".format(aList[posMax]))
        kx1, ky1, kx2, ky2 = canvas_sorting.bbox("rect_{}".format(aList[lim]))
        #print('swap:',jx1)
        if jx1 == xlim:
            pass
        else:
            canvas_sorting.move('rect_{}'.format(aList[posMax]),10,0)
        if kx1 == plim:
            pass
        else:
            canvas_sorting.move('rect_{}'.format(aList[lim]),-10,0)
        if jx1 == xlim and  kx1 == plim:
            returnBothBox(posMax,lim,aList,400)
            return
        rtMain.update()
        
        canvas_sorting.after(0,settleMax(posMax,lim,plim,xlim,aList))
    else:
        returnBox(posMax,aList,400)
        
def selectionSort (aList):
    for fillslot in range (len(aList) - 1, 0, -1):
        positionOfMax = 0
        ylim = 300
        resetBasis(positionOfMax,0,aList,ylim)
        for location in range (1, fillslot + 1):
            ylim = 370
            #liftBox(location,aList,ylim)
            if aList [location] > aList [positionOfMax]:
                #resetBasis(positionOfMax,location,aList,ylim)
                positionOfMax = location
            else:
                #returnBox(location,aList,ylim)
                pass
        temp = aList [fillslot]
        jx1, jy1, jx2, jy2 = canvas_sorting.bbox("rect_{}".format(aList[positionOfMax]))
        kx1, ky1, kx2, ky2 = canvas_sorting.bbox("rect_{}".format(aList[fillslot]))
        settleMax(positionOfMax,fillslot,jx1,kx1,aList)
        aList [fillslot] = aList [positionOfMax]
        aList[positionOfMax] = temp
       """

# %%
"""
x = random.sample(range(50),50)
print(*x)

print(*quickSort(x,0,len(x)-1,1))
"""
# Out:
# '\nx = random.sample(range(50),50)\nprint(*x)\n\nprint(*quickSort(x,0,len(x)-1,1))\n'
